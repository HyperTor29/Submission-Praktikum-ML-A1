# %% [markdown]
# ### Victorio Cristiansa Putra
# ### 24060121130084
# ### Lab A1

# %% [markdown]
# Nama Dataset : Hayesh-Roth
#
# Link Dataset : https://archive.ics.uci.edu/dataset/44/hayes+roth

# %%
# Import Library yang dibutuhkan
import pandas as pd

# %%
# Memuat dataset dari url yang sudah ditentukan
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/hayes-roth/hayes-roth.data"

names = ['name', 'hobby', 'educational-level', 'marital-status', 'class']

dataset = pd.read_csv(url, names=names)

# %%
# Melihat dimensi dataset
dataset.shape
# Out:
# (132, 5)

# %%
# Melihat isi dataset
dataset
# Out:
#      name  hobby  educational-level  marital-status  class
# 92      2      1                  1               2      1
# 10      2      1                  3               2      2
# 83      3      1                  4               1      3
# 61      2      4                  2               2      3
# 107     1      1                  3               4      3
# ..    ...    ...                ...             ...    ...
# 44      1      1                  4               3      3
# 40      2      1                  2               1      1
# 90      1      2                  1               2      2
# 21      1      2                  2               1      2
# 9       3      1                  1               2      1
#
# [132 rows x 5 columns]

# %%
# Melakukan distribusi kelas data
dataset.groupby('class').size()
# Out:
# class
# 1    51
# 2    51
# 3    30
# dtype: int64

# %%
# Melihat ringkasan statistik data
dataset.describe()
# Out:
#              name       hobby  educational-level  marital-status       class
# count  132.000000  132.000000         132.000000      132.000000  132.000000
# mean     2.000000    1.954545           1.954545        1.954545    1.840909
# std      0.819607    0.947988           0.947988        0.947988    0.769946
# min      1.000000    1.000000           1.000000        1.000000    1.000000
# 25%      1.000000    1.000000           1.000000        1.000000    1.000000
# 50%      2.000000    2.000000           2.000000        2.000000    2.000000
# 75%      3.000000    2.000000           2.000000        2.000000    2.000000
# max      3.000000    4.000000           4.000000        4.000000    3.000000

# %%
# Melihat informasi dari data
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 132 entries, 92 to 9
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               132 non-null    int64
#  1   hobby              132 non-null    int64
#  2   educational-level  132 non-null    int64
#  3   marital-status     132 non-null    int64
#  4   class              132 non-null    int64
# dtypes: int64(5)
# memory usage: 6.2 KB

# %%
# Import Library yang dibutuhkan
import matplotlib.pyplot as plt

# %%
# Memvisualisasikan data menggunakan Plot Univariat
dataset.plot(kind='box', subplots=True,layout=(2,4), sharex=False, sharey=False)
plt.show()

# %% [markdown]
# Plot tersebut menggunakan boxplot untuk menunjukkan distribusi data dari masing-masing variabel. Boxplot adalah jenis plot yang menunjukkan distribusi data secara ringkas, yaitu :
#
# 1. Median (garis tengah)
#
# 2. Mean (rata-rata)
#
# 3. Q1 (kuartil pertama)
#
# 4. Q3 (kuartil ketiga)
#
# 5. Interquartile range (IQR)
#
# 6. Outlier (nilai yang berada di luar IQR)
#
# Berdasarkan plot tersebut, dapat ditarik beberapa kesimpulan sebagai berikut:
#
# 1. Terdapat 3 kelas, yaitu kelas 1.0, kelas 2.0, dan kelas 3.0.
#
# 2. Kelas 3.0 memiliki jumlah siswa paling banyak, diikuti oleh kelas 2.0, dan kelas 1.0.
#
# 3. Hobi yang paling populer adalah 3, diikuti oleh 2, dan menonton 1.
#
# 4. Tingkat pendidikan yang paling umum adalah 3, diikuti oleh 2, dan 1.
#
# 5. Status perkawinan yang paling umum adalah 3, diikuti oleh 2, dan 1.
#
# Berikut adalah penjelasan lebih rinci mengenai masing-masing variabel :
#
# 1. Name
#
# Pada variabel name, boxplot menunjukkan bahwa jumlah siswa dengan nama yang berbeda-beda cukup bervariasi. Hal ini menunjukkan bahwa data berasal dari populasi yang heterogen.
#
# 2. Hobby
#
# Pada variabel hobby, boxplot menunjukkan bahwa hobi yang paling populer adalah 3, diikuti oleh 2, dan menonton 1. Hal ini menunjukkan bahwa kebanyakan siswa memiliki hobi yang aktif dan produktif.
#
# 3. Educational Level
#
# Pada variabel educational level, boxplot menunjukkan bahwa tingkat pendidikan yang paling umum adalah 3, diikuti oleh 2, dan 1. Hal ini menunjukkan bahwa kebanyakan siswa masih berusia muda dan belum menyelesaikan pendidikan tinggi.
#
# 4. Marital Status
#
# Pada variabel marital status, boxplot menunjukkan bahwa status perkawinan yang paling umum adalah 3, diikuti oleh 2, dan 1. Hal ini menunjukkan bahwa kebanyakan siswa masih belum menikah.
#
# 5. Class
#
# Pada variabel class, boxplot menunjukkan bahwa kelas 3.0 memiliki jumlah siswa paling banyak, diikuti oleh kelas 2.0, dan kelas 1.0. Hal ini menunjukkan bahwa kualitas siswa di kelas 3.0 lebih baik daripada kelas 2.0 dan kelas 1.0.
#
# Secara keseluruhan, plot univariat tersebut memberikan gambaran umum mengenai karakteristik dari data yang dianalisis. Plot tersebut dapat digunakan untuk mengidentifikasi pola dan tren dalam data, serta untuk membandingkan karakteristik antar kelompok data.

# %%
# Menampilkan data dalam bentuk histogram
dataset.hist()
plt.show()

# %% [markdown]
# Berdasarkan data histogram dengan 5 variabel (name, hobby, educational level, marital-status, class) yang dikirimkan, dapat disimpulkan bahwa :
#
# 1. Name (1.0, 2.0, dan 3.0) adalah nama yang paling umum, dengan frekuensi 40.
# 2. Hobby yang paling umum adalah 1 dan 2, dengan frekuensi 40.
# 3. Educational Level yang paling umum adalah 1 dan 2, dengan frekuensi 40.
# 4. Marital Status yang paling umum adalah 1 dan 2, dengan frekuensi 40.
# 5. Kelas yang paling umum adalah kelas 1.0 dan 2.0, dengan frekuensi 40.

# %%
# Memvisualisasikan data menggunakan Plot Multivariat
import pandas
from pandas.plotting import scatter_matrix
scatter_matrix(dataset)
plt.show()

# %% [markdown]
# Visualisasi data yang diberikan adalah plot multivariat dengan 5 variabel, yaitu:
#
# 1. Name
# 2. Class
# 3. Hobby
# 4. Educational Level
# 5. Marital Status
#
# Plot ini menggunakan scatterplot untuk menampilkan hubungan antara dua variabel pada satu waktu. Dalam hal ini, variabel yang ditampilkan adalah Tingkat Pendidikan dan Jumlah Orang yang Memiliki Hobi.
#
# Penjelasan:
#
# Sumbu x mewakili Educational Level, dengan permisalan kategori:
#
# SD
#
# SMP
#
# SMA
#
# D1/D2/D3
#
# S1
#
# S2
#
# S3
#
# Sumbu y mewakili Jumlah Orang yang memiliki Hobby, dengan skala dari 0 hingga 100.
# Titik pada plot mewakili data dari satu orang.
#
# Kesimpulan:
#
# 1. Secara umum, semakin tinggi tingkat pendidikan seseorang, semakin besar kemungkinannya untuk memiliki hobi.
# 2. Orang dengan tingkat pendidikan SD memiliki kemungkinan paling rendah untuk memiliki hobi, sedangkan orang dengan tingkat pendidikan S3 memiliki kemungkinan paling tinggi.
# 3. Terdapat beberapa pengecualian terhadap tren ini. Misalnya, ada orang dengan tingkat pendidikan SD yang memiliki banyak hobi, dan ada orang dengan tingkat pendidikan S3 yang tidak memiliki hobi.
#
# Penjelasan Tambahan:
#
# Dalam gambar yang diberikan, terdapat beberapa informasi tambahan yang dapat digunakan untuk menjelaskan plot lebih lanjut. Informasi tersebut adalah :
#
# Name
#
# Class
#
# Marital Status
#
# Informasi ini dapat digunakan untuk menganalisis hubungan antara variabel-variabel tersebut dengan Educational Level dan Jumlah Orang yang Memiliki Hobby. Misalnya, dapat dianalisis apakah ada hubungan antara Educational Level dan Marital Status, atau apakah ada hubungan antara Jumlah Orang yang Memiliki Hobby dan Class.
